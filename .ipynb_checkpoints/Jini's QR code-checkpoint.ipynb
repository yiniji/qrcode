# %%
# %pip install myqr
# Out:
# Collecting myqr
#   Using cached https://files.pythonhosted.org/packages/ec/ce/5ff57cde76feaa193978a28097edbb1c649e1f439182649eb9ecc7b86a03/MyQR-2.3.1.zip
# Requirement already satisfied: imageio>=1.5 in d:\anaconda3\lib\site-packages (from myqr) (2.5.0)
# Requirement already satisfied: numpy>=1.11.1 in d:\anaconda3\lib\site-packages (from myqr) (1.16.4)
# Requirement already satisfied: Pillow>=3.3.1 in d:\anaconda3\lib\site-packages (from myqr) (6.1.0)
# Building wheels for collected packages: myqr
#   Building wheel for myqr (setup.py): started
#   Building wheel for myqr (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\gordo\AppData\Local\pip\Cache\wheels\f2\34\a5\bcee822e19e5cc5adaac1f11c7c4c266d2ac762e61440b0b62
# Successfully built myqr
# Installing collected packages: myqr
# Successfully installed myqr-2.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install qrcode
# Out:
# Collecting qrcode
#   Using cached https://files.pythonhosted.org/packages/42/87/4a3a77e59ab7493d64da1f69bf1c2e899a4cf81e51b2baa855e8cc8115be/qrcode-6.1-py2.py3-none-any.whl
# Requirement already satisfied: six in d:\anaconda3\lib\site-packages (from qrcode) (1.12.0)
# Requirement already satisfied: colorama; platform_system == "Windows" in d:\anaconda3\lib\site-packages (from qrcode) (0.4.1)
# Installing collected packages: qrcode
# Successfully installed qrcode-6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from MyQR import myqr

# %%
myqr.run(words='https://github.com/yiniji', picture='cute.jpg',colorized=True)
# Out:
# line 16: mode: byte
# (4, 'H', 'D:\\ni\\qrcode\\cute_qrcode.png')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('cute_qrcode.png')
imgplot = plt.imshow(img)
